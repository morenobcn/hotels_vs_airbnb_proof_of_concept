# %% [markdown]
# # AirBnb vs Hotels.
# ## A case study, Barcelona
#
# We will explore prices and tipology of both Airbnb data as well as Hotels data in order to get insights about the competition between both.

# %% [markdown]
# ### Airbnb Data Cleansing
#
# Will follow these steps we will add the data to a dataframe and plot it in a map to make sure all looks correct.

# %%
import pandas as pd

airbnb = pd.read_csv('./data/Airbnb Listings.csv')

airbnb.head(2)
# Out:
#       id                         listing_url  \
# 0  18666  https://www.airbnb.com/rooms/18666
# 1  18674  https://www.airbnb.com/rooms/18674
#
#                                              summary  host_since  \
# 0  Apartment located near the "Plaza de las Glori...  19/01/2010
# 1  110m2 apartment to rent in Barcelona. Located ...  19/01/2010
#
#   host_response_time  host_total_listings_count   latitude  longitude  \
# 0     within an hour                       50.0  41.408886   2.185545
# 1     within an hour                       50.0  41.404197   2.173058
#
#   is_location_exact property_type         ...          bathrooms  bedrooms  \
# 0                 t     Apartment         ...                1.0       2.0
# 1                 t     Apartment         ...                2.0       3.0
#
#    beds  bed_type                                          amenities    price  \
# 0   4.0  Real Bed  {TV,Internet,Wifi,"Air conditioning","Wheelcha...  $130.00
# 1   6.0  Real Bed  {TV,Internet,Wifi,"Air conditioning","Wheelcha...  $140.00
#
#   number_of_reviews first_review  last_review review_scores_rating
# 0                 1   10/10/2015   10/10/2015                 80.0
# 1                 5   27/05/2013   18/06/2018                 85.0
#
# [2 rows x 22 columns]

# %%
#Lets filter the data to show only listings with Real Bed or Pull Out Sofa
airbnb['bed_type'].value_counts()
# Out:
# Real Bed         17625
# Pull-out Sofa      112
# Futon               38
# Couch                8
# Airbed               5
# Name: bed_type, dtype: int64

# %%
bed_types_list = ['Real Bed', 'Pull-out Sofa']

airbnb = airbnb.loc[airbnb['bed_type'].isin(bed_types_list)]

airbnb.head(2)
# Out:
#       id                         listing_url  \
# 0  18666  https://www.airbnb.com/rooms/18666
# 1  18674  https://www.airbnb.com/rooms/18674
#
#                                              summary  host_since  \
# 0  Apartment located near the "Plaza de las Glori...  19/01/2010
# 1  110m2 apartment to rent in Barcelona. Located ...  19/01/2010
#
#   host_response_time  host_total_listings_count   latitude  longitude  \
# 0     within an hour                       50.0  41.408886   2.185545
# 1     within an hour                       50.0  41.404197   2.173058
#
#   is_location_exact property_type         ...          bathrooms  bedrooms  \
# 0                 t     Apartment         ...                1.0       2.0
# 1                 t     Apartment         ...                2.0       3.0
#
#    beds  bed_type                                          amenities    price  \
# 0   4.0  Real Bed  {TV,Internet,Wifi,"Air conditioning","Wheelcha...  $130.00
# 1   6.0  Real Bed  {TV,Internet,Wifi,"Air conditioning","Wheelcha...  $140.00
#
#   number_of_reviews first_review  last_review review_scores_rating
# 0                 1   10/10/2015   10/10/2015                 80.0
# 1                 5   27/05/2013   18/06/2018                 85.0
#
# [2 rows x 22 columns]

# %%
#just to check
airbnb['bed_type'].value_counts()
# Out:
# Real Bed         17625
# Pull-out Sofa      112
# Name: bed_type, dtype: int64

# %%
#Also we need listings with at least 5 reviews during the last year
airbnb.dtypes

#we see we dont have a date column so will need to create it
# Out:
# id                             int64
# listing_url                   object
# summary                       object
# host_since                    object
# host_response_time            object
# host_total_listings_count    float64
# latitude                     float64
# longitude                    float64
# is_location_exact             object
# property_type                 object
# room_type                     object
# accommodates                   int64
# bathrooms                    float64
# bedrooms                     float64
# beds                         float64
# bed_type                      object
# amenities                     object
# price                         object
# number_of_reviews              int64
# first_review                  object
# last_review                   object
# review_scores_rating         float64
# dtype: object

# %%
#Create date column
airbnb['last_review'] = pd.to_datetime(airbnb['last_review'])
#airbnb.dtypes #jsut to check

#filter by last year (american notation!!) and with at least 5 reviews in total
airbnb = airbnb[(airbnb['last_review'] > '8/10/2017') & (airbnb['last_review'] < '7/10/2018') & (airbnb['number_of_reviews'] > 4) ]

#check
print (airbnb['last_review'].min())
print (airbnb['last_review'].max())
print (airbnb['number_of_reviews'].min())
# Out:
# 2017-08-11 00:00:00
# 2018-07-07 00:00:00
# 5

# %%
airbnb.count()
#we almost reduced by 50% the original number of listings
# Out:
# id                           9251
# listing_url                  9251
# summary                      8957
# host_since                   9249
# host_response_time           8965
# host_total_listings_count    9249
# latitude                     9251
# longitude                    9251
# is_location_exact            9251
# property_type                9251
# room_type                    9251
# accommodates                 9251
# bathrooms                    9242
# bedrooms                     9246
# beds                         9246
# bed_type                     9251
# amenities                    9251
# price                        9251
# number_of_reviews            9251
# first_review                 9250
# last_review                  9251
# review_scores_rating         9250
# dtype: int64

# %%
#change prices to float 
airbnb['price'] = airbnb['price'].replace('[\$,]', '', regex=True).astype(float)

# %%
#export airbnb data
airbnb.to_csv('./data/Airbnb_for_analysis.csv')

# %% [markdown]
# ### Hotels dataset from Tripadvisor

# %%
#read the hotels data that we will need to merge in a single dataframe
columns_list = ['Hotel Name', 'Price (USD)', 'Number of reviews', 'Reviews rating (out of 5)', 'Ranking (best value)', 'Hotel Link']
hotels_list = pd.read_csv('./data/Full Hotel list with Links.csv', header=None, names = columns_list)
columns_details = ['Hotel Address', 'Hotel Link','User Reviews Ratings','Stars Rating', 'Average reviews','Excellent reviews' ,'Poor reviews', 'Terrible reviews', 'Very Good reviews', ]
hotels_details = pd.read_csv('./data/Hotel Details.csv', skiprows=1, names = columns_details)
                             
#merge both datasets based on the h_link which is the common field
hotels = pd.merge(hotels_list, hotels_details, on='Hotel Link')
hotels.to_csv('./data/hotels_to_geocode.csv')

# %% [markdown]
# Once data is geocoded with ArcGIS online tools we bring it back to the notebook to proceed with the analysis, we have two new columsn with the lat and longitude for each hotel

# %%
#get teh data back
hotels = pd.read_csv('./data/Hotels_Joined_Geocoded.csv')
hotels.head(2)
# Out:
#            Hotel Name  Price (USD)  Number of reviews  \
# 0   Hotel Via Augusta         67.0                999
# 1    Hotel The Serras        263.0               1057
# 2             Andante         78.0               1872
# 3       Hotel Astoria         61.0               1282
# 4  NH Sants Barcelona         77.0               1523
#
#    Reviews rating (out of 5)  Ranking (best value)  \
# 0                        4.0                  51.0
# 1                        5.0                  52.0
# 2                        4.5                  53.0
# 3                        4.0                  54.0
# 4                        4.0                  55.0
#
#                                           Hotel Link  \
# 0  https://www.tripadvisor.com/Hotel_Review-g1874...
# 1  https://www.tripadvisor.com/Hotel_Review-g1874...
# 2  https://www.tripadvisor.com/Hotel_Review-g1874...
# 3  https://www.tripadvisor.com/Hotel_Review-g1874...
# 4  https://www.tripadvisor.com/Hotel_Review-g1874...
#
#                                        Hotel Address  User Reviews Ratings  \
# 0            Via Augusta 63 , 08006 Barcelona, Spain                 193.0
# 1       Passeig de Colom, 9 , 08002 Barcelona, Spain                   1.0
# 2  Drassanes, 23-25 , Raval, Ciutat Vella08001 Ba...                 108.0
# 3                Paris, 203 , 08036 Barcelona, Spain                 132.0
# 4              Numancia, 74 , 08029 Barcelona, Spain                 222.0
#
#    Stars Rating  Average reviews  Excellent reviews  Poor reviews  \
# 0           4.0             55.0              104.0          13.0
# 1           5.0              5.0              750.0           2.0
# 2           3.0             60.0              514.0          12.0
# 3           3.0             93.0              258.0          19.0
# 4           4.0             66.0               96.0          18.0
#
#    Terrible reviews  Very Good reviews  FID         x          y
# 0               5.0              140.0    1  2.151556  41.400132
# 1               0.0               51.0    2  2.181013  41.380084
# 2               9.0              373.0    3  2.172653  41.376745
# 3               9.0              286.0    4  2.153568  41.393906
# 4               7.0              132.0    5  2.137737  41.384528

# %% [markdown]
# We are going to "normalize" the star ratings data so goes only from 1 to 5, there are some in between.

# %%
#we Will be using the cut function to create the different bins
    
hotels['Stars Rating Categories'] = pd.cut(hotels['Stars Rating'],5, labels=["1 Star Hotel", "2 Star Hotel", "3 Star Hotel", "4 Star Hotel", "5 Star Hotel"])

hotels.to_csv('./data/Hotels Merged Enriched.csv')

# %% [markdown]
# ## Final data Visualization using CartoFrames

# %%
# we inizialize the carto context
import cartoframes
from cartoframes import CartoContext, BaseMap, Layer, styling
cc = CartoContext(base_url='https://natxnycdsa.carto.com', api_key='d2ec96729a519abe420c8f1696d485ba7c48047e')

#once connected we will write our dataset into our CARTO account
hotels_final = pd.read_csv('Hotels_to_Map.csv')
airbnb_final = pd.read_csv('./data/Airbnb_to_map.csv')
hotels_final.head(2)
airbnb_final.head(2)
# Out:
#    X1     id                         listing_url  \
# 0   2  19157  https://www.airbnb.com/rooms/19157
# 1   4  25786  https://www.airbnb.com/rooms/25786
#
#                                              summary  host_since  \
# 0  We offer a Room in a very well located apartme...  24/01/2010
# 1  JUST GO THROUGH THE MANY REVIEWS I GOT THROUGH...  14/04/2010
#
#   host_response_time  host_total_listings_count   latitude  longitude  \
# 0     within an hour                        2.0  41.407929   2.174540
# 1     within an hour                        1.0  41.401452   2.156447
#
#   is_location_exact          ...          bathrooms bedrooms  beds  bed_type  \
# 0                 t          ...                1.0      1.0   1.0  Real Bed
# 1                 t          ...                1.0      1.0   1.0  Real Bed
#
#                                            amenities  price number_of_reviews  \
# 0  {Internet,Wifi,Kitchen,"Smoking allowed",Eleva...     30               165
# 1  {TV,Wifi,"Air conditioning",Kitchen,Elevator,H...     42               191
#
#   first_review  last_review  review_scores_rating
# 0   18/08/2010   2018-06-23                    89
# 1   11/08/2010   2018-06-07                    95
#
# [2 rows x 23 columns]

# %%
#we save the data into our carto account
cc.write(hotels_final, 'Hotels_vs_Airbnb', lnglat=('x', 'y'),overwrite=True)
cc.write(airbnb_final, 'Airbnb_BCN_filtered', lnglat=('longitude', 'latitude'),overwrite=True)

# %% [markdown]
# **We will create a simple map to visualize the data and will use the CARTO builder for the final product**

# %%
cc.map(lat=41.395527, lng=2.1749063, zoom=12)
cc.map(layers=[
    BaseMap('dark'),
    Layer('hotels_vs_airbnb', size={
            'column': 'price_usd_',
            'min': 4,
            'max': 12,
            'bin_method': 'quantiles'
        }, color = '#E30613')
    ])
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html>
#   <head>
#     <title>Carto</title>
#     <meta name='viewport' content='initial-scale=1.0, user-scalable=no' />
#     <meta http-equiv='content-type' content='text/html; charset=UTF-8' />
#     <link rel='shortcut icon' href='http://cartodb.com/assets/favicon.ico' />
#
#     <style>
#      html, body, #map {
#        height: 100%;
#        padding: 0;
#        margin: 0;
#      }
#      #zoom-center {
#        position: absolute;
#        right: 0;
#        top: 0;
#        background-color: rgba(255, 255, 255, 0.7);
#        width: 240px;
#        z-index: 100;
#        padding: 4px;
#      }
#     </style>
#
#     <link rel='stylesheet' href='https://cartodb-libs.global.ssl.fastly.net/cartodb.js/v3/3.15/themes/css/cartodb.css' />
#   </head>
#   <body>
#     <div id='zoom-center'>
#       zoom=<span id='zoom'>4</span>,
#       lng=<span id='lon'>No data</span>, lat=<span id='lat'>No data</span>
#     </div>
#     <div id='map'></div>
#     <script src='https://cartodb-libs.global.ssl.fastly.net/cartodb.js/v3/3.15/cartodb.js'></script>
#
#     <script>
#      const config  = {&quot;user_name&quot;: &quot;natxnycdsa&quot;, &quot;maps_api_template&quot;: &quot;https://natxnycdsa.carto.com&quot;, &quot;sql_api_template&quot;: &quot;https://natxnycdsa.carto.com&quot;, &quot;tiler_protocol&quot;: &quot;https&quot;, &quot;tiler_domain&quot;: &quot;carto.com&quot;, &quot;tiler_port&quot;: &quot;80&quot;, &quot;type&quot;: &quot;namedmap&quot;, &quot;named_map&quot;: {&quot;name&quot;: &quot;cartoframes_ver20170406_layers1_time0_baseid1_labels0_zoom0&quot;, &quot;params&quot;: {&quot;basemap_url&quot;: &quot;https://{s}.basemaps.cartocdn.com/rastertiles/dark_all/{z}/{x}/{y}.png&quot;, &quot;cartocss_0&quot;: &quot;#layer {  marker-width: ramp([price_usd_], range(4,12), quantiles(5)); marker-fill: #E30613; marker-fill-opacity: 1; marker-allow-overlap: true; marker-line-width: 0.5; marker-line-color: #000; marker-line-opacity: 1;}&quot;, &quot;sql_0&quot;: &quot;SELECT * FROM hotels_vs_airbnb&quot;, &quot;west&quot;: 1.75125263429412, &quot;south&quot;: 41.2680186546394, &quot;east&quot;: 2.44488812031508, &quot;north&quot;: 41.8240620000402}}};
#      const bounds  = [[41.8240620000402, 2.44488812031508], [41.2680186546394, 1.75125263429412]];
#      const options = {&quot;filter&quot;: [&quot;mapnik&quot;, &quot;torque&quot;], &quot;https&quot;: true};
#
#      const adjustLongitude = (lng) => (
#        lng - ((Math.ceil((lng + 180) / 360) - 1) * 360)
#      );
#      const map = L.map('map', {
#        zoom: 3,
#        center: [0, 0],
#      });
#
#      if (L.Browser.retina) {
#          var basemap = config.named_map.params.basemap_url.replace('.png', '@2x.png');
#      } else {
#          var basemap = config.named_map.params.basemap_url;
#      }
#      L.tileLayer(basemap, {
#          attribution: &quot;&copy; <a href=\&quot;http://www.openstreetmap.org/copyright\&quot;>OpenStreetMap</a>&quot;
#      }).addTo(map);
#      const updateMapInfo = () => {
#        $('#zoom').text(map.getZoom());
#        $('#lat').text(map.getCenter().lat.toFixed(4));
#        $('#lon').text(adjustLongitude(map.getCenter().lng).toFixed(4));
#      };
#
#      cartodb.createLayer(map, config, options)
#             .addTo(map)
#             .done((layer) => {
#               if (bounds.length) {
#                 map.fitBounds(bounds);
#               }
#               updateMapInfo();
#               map.on('move', () => {
#                 updateMapInfo();
#               });
#             })
#             .error((err) => {
#               console.log('ERROR: ', err);
#             });
#     </script>
#
#   </body>
# </html>
# " width=800 height=400>  Preview image: <img src="https://natxnycdsa.carto.com/api/v1/map/static/named/cartoframes_ver20170406_layers1_time0_baseid1_labels0_zoom0/800/400.png?config=%7B%22basemap_url%22%3A+%22https%3A%2F%2F%7Bs%7D.basemaps.cartocdn.com%2Frastertiles%2Fdark_all%2F%7Bz%7D%2F%7Bx%7D%2F%7By%7D.png%22%2C+%22cartocss_0%22%3A+%22%23layer+%7B++marker-width%3A+ramp%28%5Bprice_usd_%5D%2C+range%284%2C12%29%2C+quantiles%285%29%29%3B+marker-fill%3A+%23E30613%3B+marker-fill-opacity%3A+1%3B+marker-allow-overlap%3A+true%3B+marker-line-width%3A+0.5%3B+marker-line-color%3A+%23000%3B+marker-line-opacity%3A+1%3B%7D%22%2C+%22sql_0%22%3A+%22SELECT+%2A+FROM+hotels_vs_airbnb%22%7D&anti_cache=0.5824078625672157&bbox=1.75125263429412%2C41.2680186546394%2C2.44488812031508%2C41.8240620000402" /></iframe>
